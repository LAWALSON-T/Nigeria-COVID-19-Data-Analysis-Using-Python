# %% [markdown]
# Interested in seeing the relationship between the Covid virus infection rate and population in regards to each states size , that is the Population density against confirmed cases.

# %% [markdown]
# The best way to do this is to plot a diagram displaying the map of Nigeria , using each states geographical segmentation as an idea of each states size
#
# Then using colour variation to show the number of confirmed cases per each states while also annotating their population density on the map

# %% [markdown]
# In other to plot the map of Nigeria, We need a shapely data 'shapefiles(.shp)', the data needs to be in polygon or multipolygon format
#
# Also employ the Geopandas Dataframe, Geopandas makes working easier with geospatial data (data that has a geographic component to it) in Python.

# %%
import requests
import numpy as np
import urllib.request
import pandas as pd
import csv
from bs4 import BeautifulSoup
import seaborn as sns
sns.set_style("darkgrid")
plt.style.use('fivethirtyeight')
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(12,8)})

# %% [markdown]
# ### Data extraction

# %%
# lets scrape the ncdc data used in the previos repository
url='https://covid19.ncdc.gov.ng/'

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'lxml')

# %%
table=soup.find('div', {'class':'table-responsive'})

# %%
headers=[]

for i in table.find_all('th'):
    title=i.text
    headers.append(title)

# %%
df1=pd.DataFrame(columns=headers)

# %%
for row in table.find_all('tr')[1:]:
    data=row.find_all('td')
    row_data=[td.text.strip() for td in data]
    length=len(df1)
    df1.loc[length]=row_data

# %%
df1.head()
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                      104,231                       1,088
# 1             FCT                       29,530                          12
# 2          Rivers                       18,108                          -3
# 3          Kaduna                       11,630                           1
# 4             Oyo                       10,352                           0
#
#   No. Discharged No. of Deaths
# 0        102,372           771
# 1         29,269           249
# 2         17,956           155
# 3         11,540            89
# 4         10,150           202

# %%
import geopandas as gpd

# %%
# getting the shapely data that has a geometry column containing multipolygon values for each state
url= ('https://raw.githubusercontent.com/Enoch768/Nigeria-Weather/main/Niger_geojson.geojson')
df = gpd.read_file(url)

# %%
df.head()
# Out:
#   admin1Name admin1Pcod admin1RefN admin1AltN admin1Al_1 admin0Name  \
# 0       Abia      NG001       Abia       None       None    Nigeria
# 1    Adamawa      NG002    Adamawa       None       None    Nigeria
# 2  Akwa Ibom      NG003  Akwa Ibom       None       None    Nigeria
# 3    Anambra      NG004    Anambra       None       None    Nigeria
# 4     Bauchi      NG005     Bauchi       None       None    Nigeria
#
#   admin0Pcod        date     validOn validTo  Shape_Leng  Shape_Area  \
# 0         NG  2016-11-29  2016-12-15    None    4.695135    0.396543
# 1         NG  2016-11-29  2016-12-15    None   11.525443    3.113007
# 2         NG  2016-11-29  2016-12-15    None    5.263830    0.549476
# 3         NG  2016-11-29  2016-12-15    None    3.595960    0.392661
# 4         NG  2016-11-29  2016-12-15    None   13.952005    4.011018
#
#                                             geometry
# 0  MULTIPOLYGON (((7.38681 6.03667, 7.38729 6.036...
# 1  MULTIPOLYGON (((13.62129 10.94823, 13.62592 10...
# 2  MULTIPOLYGON (((8.34482 4.61140, 8.34496 4.609...
# 3  MULTIPOLYGON (((6.93254 6.71090, 6.93167 6.698...
# 4  MULTIPOLYGON (((10.75125 12.46148, 10.75615 12...

# %%
# Data containing population and poulation density used in previous repository
url='https://github.com/Ustacky-dev/Nigeria-COVID-19-Data-Analysis-Using-Python/blob/main/covid_external.csv?raw=True'
covid=pd.read_csv(url)

# %%
covid.head()
# Out:
#       states         region  Population  Overall CCVI Index  Age  \
# 0        FCT  North Central     4865000                 0.3  0.0
# 1    Plateau  North Central     4766000                 0.4  0.5
# 2      Kwara  North Central     3524000                 0.3  0.4
# 3  Nassarawa  North Central     2783000                 0.1  0.3
# 4      Niger  North Central     6260000                 0.6  0.0
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.9        0.4            0.6                 0.9
# 1              0.4        0.8            0.3                 0.3
# 2              0.3        0.2            0.4                 0.2
# 3              0.5        0.9            0.0                 0.1
# 4              0.6        0.3            0.7                 0.1
#
#    Socio-Economic   Transport Availability  Acute IHR
# 0             0.6                      0.2       0.79
# 1             0.5                      0.3       0.93
# 2             0.6                      0.7       0.93
# 3             0.6                      0.5       0.85
# 4             0.8                      0.8       0.84

# %% [markdown]
# ### DATA PROCESSING

# %%
df2= covid[['states','Population','Population Density']]

# %%
df2.head()
# Out:
#       states  Population  Population Density
# 0        FCT     4865000                 0.9
# 1    Plateau     4766000                 0.3
# 2      Kwara     3524000                 0.2
# 3  Nassarawa     2783000                 0.1
# 4      Niger     6260000                 0.1

# %%
df2.rename(columns={'states': 'States Affected'}, inplace= True)
df2['States Affected']=df2['States Affected'].replace({'Nassarawa':'Nasarawa'})

# %%
df['admin1Name']=df['admin1Name'].replace({'Federal Capital Territory':'FCT'})
df.rename(columns={'admin1Name': 'States Affected'}, inplace= True)

# %%
# merge all three datasets
merged=df.merge(df1,on='States Affected').merge(df2,on='States Affected')
merged.set_index('States Affected', inplace= True)

# %%
merged.head()
# Out:
#                 admin1Pcod admin1RefN admin1AltN admin1Al_1 admin0Name  \
# States Affected
# Abia                 NG001       Abia       None       None    Nigeria
# Adamawa              NG002    Adamawa       None       None    Nigeria
# Akwa Ibom            NG003  Akwa Ibom       None       None    Nigeria
# Anambra              NG004    Anambra       None       None    Nigeria
# Bauchi               NG005     Bauchi       None       None    Nigeria
#
#                 admin0Pcod        date     validOn validTo  Shape_Leng  \
# States Affected
# Abia                    NG  2016-11-29  2016-12-15    None    4.695135
# Adamawa                 NG  2016-11-29  2016-12-15    None   11.525443
# Akwa Ibom               NG  2016-11-29  2016-12-15    None    5.263830
# Anambra                 NG  2016-11-29  2016-12-15    None    3.595960
# Bauchi                  NG  2016-11-29  2016-12-15    None   13.952005
#
#                  Shape_Area  \
# States Affected
# Abia               0.396543
# Adamawa            3.113007
# Akwa Ibom          0.549476
# Anambra            0.392661
# Bauchi             4.011018
#
#                                                           geometry  \
# States Affected
# Abia             MULTIPOLYGON (((7.38681 6.03667, 7.38729 6.036...
# Adamawa          MULTIPOLYGON (((13.62129 10.94823, 13.62592 10...
# Akwa Ibom        MULTIPOLYGON (((8.34482 4.61140, 8.34496 4.609...
# Anambra          MULTIPOLYGON (((6.93254 6.71090, 6.93167 6.698...
# Bauchi           MULTIPOLYGON (((10.75125 12.46148, 10.75615 12...
#
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Abia                                   2,263                           0
# Adamawa                                1,312                         134
# Akwa Ibom                              5,010                           6
# Anambra                                2,825                          46
# Bauchi                                 2,028                           2
#
#                 No. Discharged No. of Deaths  Population  Population Density
# States Affected
# Abia                     2,229            34     4190000                 0.9
# Adamawa                  1,140            38     4672000                 0.3
# Akwa Ibom                4,960            44     6093000                 0.8
# Anambra                  2,760            19     6050000                 1.0
# Bauchi                   2,002            24     7270000                 0.2

# %% [markdown]
# ### MAP PLOT

# %%
variable = 'No. of Cases (Lab Confirmed)'
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
merged.plot(column=variable, cmap='BuGn', linewidth=0.8, ax=ax, edgecolor='0.8')
# remove the axis
ax.axis("off")
# add a title
ax.set_title('Confirmed cases / Population density', fontdict={'fontsize': '25', 'fontweight' : '3'})

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='BuGn', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)
#saving our map as .png file.


for coord, label in zip(merged.geometry, merged.index,):
    ax.annotate(label, xy=(coord.centroid.coords[0]), xytext=(3,3), textcoords='offset points',va='bottom',ha='center',weight='bold')
for coord, label in zip(merged.geometry, merged['Population Density']):
    ax.annotate(label, xy=(coord.centroid.coords[0]), xytext=(3,3), textcoords='offset points', ha='center',va='top')
    
plt.gcf().text(0.002, 1.30,'Graphical representation of the number of confirmed cases per each state', fontsize=14)
plt.gcf().text(0.002, 1.25, 'There is an appreciable correlation between the population density and number of confirmed cases', fontsize=10)
plt.gcf().text(0.002, 1.20, 'Some states with high number of confirmed cases have a high population density', fontsize=10)
plt.gcf().text(0.002, 1.15, 'Most states in the North with large areas and low population density show very low number of confirmed cases', fontsize=10)
plt.gcf().text(0.002, 1.10, 'States in the West with smaller areas and high population density show high number of confirmed cases', fontsize=10)
plt.gcf().text(0.90,0.30, 'States in the Eastern region dont show much correlation', fontsize=10)
plt.gcf().text(0.90,0.25, 'The colour variation of Lagos doesnt seem to tally with the reports', fontsize=10)
#saving our map as .png file.
plt.savefig('figure5.png', bbox_inches='tight')
